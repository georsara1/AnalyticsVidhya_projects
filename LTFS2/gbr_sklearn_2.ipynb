# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import gc
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold
import time
from datetime import timedelta, date
from fastai.tabular import *

# %matplotlib inline

# %%
train_df = pd.read_csv('train.csv')
test_df =  pd.read_csv('test.csv')

# %%
d = pd.DataFrame(train_df.groupby(['application_date', 'segment'])['case_count'].sum())

# %%
train = pd.DataFrame(train_df.groupby(['application_date', 'segment'])['case_count'].sum())
train.reset_index(inplace=True)

# %%
add_datepart(train, 'application_date', drop = False)
add_cyclic_datepart(train, 'application_date')

add_datepart(test_df, 'application_date', drop = False)
add_cyclic_datepart(test_df, 'application_date')
# Out:
#       id  segment  application_Year  application_Month  application_Week  \
# 0      1        1              2019                  7                27
# 1      2        1              2019                  7                27
# 2      3        1              2019                  7                28
# 3      4        1              2019                  7                28
# 4      5        1              2019                  7                28
# ..   ...      ...               ...                ...               ...
# 175  176        2              2019                 10                42
# 176  177        2              2019                 10                43
# 177  178        2              2019                 10                43
# 178  179        2              2019                 10                43
# 179  180        2              2019                 10                43
#
#      application_Day  application_Dayofweek  application_Dayofyear  \
# 0                  6                      5                    187
# 1                  7                      6                    188
# 2                  8                      0                    189
# 3                  9                      1                    190
# 4                 10                      2                    191
# ..               ...                    ...                    ...
# 175               20                      6                    293
# 176               21                      0                    294
# 177               22                      1                    295
# 178               23                      2                    296
# 179               24                      3                    297
#
#      application_Is_month_end  application_Is_month_start  ...  \
# 0                       False                       False  ...
# 1                       False                       False  ...
# 2                       False                       False  ...
# 3                       False                       False  ...
# 4                       False                       False  ...
# ..                        ...                         ...  ...
# 175                     False                       False  ...
# 176                     False                       False  ...
# 177                     False                       False  ...
# 178                     False                       False  ...
# 179                     False                       False  ...
#
#      application_Is_year_start  application_Elapsed  application_weekday_cos  \
# 0                        False           1562371200                -0.222521
# 1                        False           1562457600                 0.623490
# 2                        False           1562544000                 1.000000
# 3                        False           1562630400                 0.623490
# 4                        False           1562716800                -0.222521
# ..                         ...                  ...                      ...
# 175                      False           1571529600                 0.623490
# 176                      False           1571616000                 1.000000
# 177                      False           1571702400                 0.623490
# 178                      False           1571788800                -0.222521
# 179                      False           1571875200                -0.900969
#
#      application_weekday_sin  application_day_month_cos  \
# 0                  -0.974928                   0.528964
# 1                  -0.781831                   0.347305
# 2                   0.000000                   0.151428
# 3                   0.781831                  -0.050649
# 4                   0.974928                  -0.250653
# ..                       ...                        ...
# 175                -0.781831                  -0.758758
# 176                 0.000000                  -0.612106
# 177                 0.781831                  -0.440394
# 178                 0.974928                  -0.250653
# 179                 0.433884                  -0.050649
#
#      application_day_month_sin  application_month_year_cos  \
# 0                     0.848644               -1.000000e+00
# 1                     0.937752               -1.000000e+00
# 2                     0.988468               -1.000000e+00
# 3                     0.998717               -1.000000e+00
# 4                     0.968077               -1.000000e+00
# ..                         ...                         ...
# 175                  -0.651372               -1.836970e-16
# 176                  -0.790776               -1.836970e-16
# 177                  -0.897805               -1.836970e-16
# 178                  -0.968077               -1.836970e-16
# 179                  -0.998717               -1.836970e-16
#
#      application_month_year_sin  application_day_year_cos  \
# 0                  1.224647e-16                 -0.998186
# 1                  1.224647e-16                 -0.997001
# 2                  1.224647e-16                 -0.995521
# 3                  1.224647e-16                 -0.993747
# 4                  1.224647e-16                 -0.991677
# ..                          ...                       ...
# 175               -1.000000e+00                  0.309017
# 176               -1.000000e+00                  0.325342
# 177               -1.000000e+00                  0.341571
# 178               -1.000000e+00                  0.357698
# 179               -1.000000e+00                  0.373720
#
#      application_day_year_sin
# 0                   -0.060213
# 1                   -0.077386
# 2                   -0.094537
# 3                   -0.111659
# 4                   -0.128748
# ..                        ...
# 175                 -0.951057
# 176                 -0.945596
# 177                 -0.939856
# 178                 -0.933837
# 179                 -0.927542
#
# [180 rows x 23 columns]

# %%
train_x = train.drop(['case_count'],axis = 1)
train_y = train['case_count']

# %%
cont_names, cat_names = cont_cat_split(df=train_x, max_card=100)

# %%
tfm = FillMissing(cat_names, cont_names)
tfm(train_x)

# %%
# train_x = train_x.drop(['application_Is_year_end','application_Is_year_start'], axis = 1)
# test_df = test_df.drop(['application_Is_year_end','application_Is_year_start'], axis = 1)

# %%
train_x_early, valid_x_early, train_y_early, valid_y_early = train_test_split(train_x,train_y,test_size = 0.2)

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
reg1 = GradientBoostingRegressor(loss='ls', learning_rate=0.1, n_estimators=150, subsample=1.0, criterion='mse', 
                                 min_samples_split=5, min_samples_leaf=2, min_weight_fraction_leaf=0.0, max_depth=10, 
                                 min_impurity_decrease=1.0, min_impurity_split=None, init=None, random_state=None, 
                                 max_features=None, alpha=0.8, verbose=0, max_leaf_nodes=None, warm_start=False, 
                                 validation_fraction=0.1, n_iter_no_change=None, tol=0.0001)
reg1.fit(train_x_early, train_y_early)
# Out:
# GradientBoostingRegressor(alpha=0.8, criterion='mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=10,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=1.0, min_impurity_split=None,
#                           min_samples_leaf=2, min_samples_split=5,
#                           min_weight_fraction_leaf=0.0, n_estimators=150,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
train_pred_early = reg1.predict(train_x_early)
train_pred_valid = reg1.predict(valid_x_early)

# %%
print('Train mape: {}'.format(mean_absolute_percentage_error(train_y_early,train_pred_early)))
print('Valid mape: {}'.format(mean_absolute_percentage_error(valid_y_early,train_pred_valid)))
# Out:
# Train mape: 8.382042044360194
# Valid mape: 88.77454034507518

# %%
#23.567015

# %%
test = test_df.drop(['id'], axis = 1)
test_pred = reg1.predict(test)

# %%
test_pred
# Out:
# array([ 1701.306549,  1098.236832,  2212.348842,  1702.40836 , ..., 22869.936562, 25493.482715, 28794.864678,
#        30010.807122])

# %%
sub = pd.read_csv('sample_submission.csv')
sub['case_count'] = test_pred
sub.to_csv('gbr2.csv',index = False)

# %%
plt.hist(train_y_early, label = 'train')
plt.hist(valid_y_early, label = 'valid')
plt.hist(test_pred, label = 'test')
plt.legend()

# %%
imp = reg1.feature_importances_
features = train_x_early.columns

importance_df = pd.DataFrame({'feature': features, 'importance': imp})

# %%
importance_df.sort_values(by = 'importance', ascending = False)
# Out:
#                          feature    importance
# 0                        segment  4.198594e-01
# 4                application_Day  2.056134e-01
# 16     application_day_month_cos  1.268548e-01
# 13           application_Elapsed  1.171457e-01
# 17     application_day_month_sin  3.775885e-02
# 5          application_Dayofweek  2.978176e-02
# 21      application_day_year_sin  1.950637e-02
# 6          application_Dayofyear  9.056719e-03
# 7       application_Is_month_end  7.690163e-03
# 20      application_day_year_cos  7.437309e-03
# 15       application_weekday_sin  4.377792e-03
# 19    application_month_year_sin  3.776226e-03
# 14       application_weekday_cos  3.140516e-03
# 18    application_month_year_cos  2.878674e-03
# 3               application_Week  2.096956e-03
# 2              application_Month  1.488533e-03
# 1               application_Year  7.687225e-04
# 9     application_Is_quarter_end  6.986522e-04
# 10  application_Is_quarter_start  5.759401e-05
# 8     application_Is_month_start  1.187249e-05
# 11       application_Is_year_end  2.000858e-08
# 12     application_Is_year_start  0.000000e+00
